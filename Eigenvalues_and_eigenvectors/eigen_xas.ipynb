# %% [markdown]
# # Eigenvalue and Eigenvectors
#  Los vectores propios, autovectores o eingenvectores de un operador lineal son los vectores no nulos que, cuando son transformados por el operador, dan lugar a un multiplo escalar de si mismos, con lo que no cambian su direccion. Los terminos eingenvalor y eingevector corresponden a valor propio y vector propio correspondiente.
#
#  *Sea A una matriz cuadrada, v un vector propio y lambda, un escalar que satisface Av=lambda v, entonces lambda es llamado el valor propio asociado con el vector propio v de A*
#
# Los valores propios de A son las raices de la ecuacion caracteriticas  det (*A* - \lambda I)
#
#
#  Ejemplo: Encontrar los valores y vectores propios de la matriz A
#  \begin{pmatrix} 3.2 & -1 & 2 \\ 2 & -2 & 4 \\ 1.5 & -1 & -4 \end{pmatrix}
#
#  1.- Solucion a papel y lapiz
#  De acuerdo a lo mencionado anteriormente se tiene:
#  ![eigen1.png](attachment:eigen1.png)
#  Multiplciacion de escalares: al multiplicar cada elemento de la matriz por un escalar se tiene
#  ![eing2.png](attachment:eing2.png)
#  aplicando la ecuacion caracteristica
# ![eing3.png](attachment:eing3.png)
# Se obtendra =
#    \begin{pmatrix} 3.2-\lambda  & (-1)-0 & 2-0 \\ 2-0 & (-2)-4 & 4-0 \\ 1.5-0 & (-1)-0 & (-4)-\lambda  \end{pmatrix}
#   simplificando=
#   \begin{pmatrix} 3.2-\lambda \quad  & -1 & 2 \\ 2 & -2-\lambda  & 4 \\ 1.5 & -1 & -4-\lambda  \end{pmatrix}
#   A esta nueva matrices se debe de encontrar la determinante mediante la formula general que a continuacion se muestra:
#   ![daum_equation_1543559244669.png](attachment:daum_equation_1543559244669.png)
#   sustituyendo:
#   ![matinv.png](attachment:matinv.png)
#   se encontrara la determinante de la matriz mediante la formula:
#
#   ![det.png](attachment:det.png)
#    Aplicandola tenemos=
#    \begin{pmatrix} -2-\lambda  & 4 \\ -1 & -4-\lambda  \end{pmatrix}
#    ![daum_e1.png](attachment:daum_e1.png)
#    para :
#    \begin{pmatrix} 2 & 4 \\ 1.5 & -4-\lambda  \end{pmatrix}
#    ![daum1.png](attachment:daum1.png)
#
#    Por ultimo:
#    \begin{pmatrix} 2 & -2-\lambda  \\ 1.5 & -1 \end{pmatrix}
#
#    ![porultimo.png](attachment:porultimo.png)
#
#    Sustitutendo en la formula general:
#
#  ![sustitu.png](attachment:sustitu.png)
#
#   Simplificando obtenemos:
# ![simpli.png](attachment:simpli.png)
#
#   Multiplicando ambos valores por diez
#  ![por10.png](attachment:por10.png)
#  Despues de haber obtenido la ecuacion por el metodo de *Newton - Raphson* se obtendra mediante un proceso iterativo para aproximarse a la raiz de una función.
#  ![NewtonRp.png](attachment:NewtonRp.png)
#
#  aplicando
#  ![nwr.png](attachment:nwr.png)
#
#  Despues de 18 iteraciones en la 19 se obtiene:
#
#  ![finalvec.png](attachment:finalvec.png)
#  Los valores propios son: *2.965908..*
#
#  Para el vector propio se tiene:
#   *Se A una matriz cuadrada, v un vector y lambda un escalar que satisface Av=lambda * v, entonces v es un vector propio de A y lanbda es el valor propoio asociado a el.*
#  ![vec1.png](attachment:vec1.png)
#
#  Una vez encotrado el valor propio se obtiene el vector propio aplicando lo anterior mencionado:
#  ![susitvalor.png](attachment:susitvalor.png)
#
#  Se reducio la matriz por medio de la forma escalonada, este metodo consiste en intercalar las filas de la matriz e ir multiplicando, quedando de la siguiente manera:
#  ![result.png](attachment:result.png)
#   De acuerdo al valor propio:
#   ![resultfinal.png](attachment:resultfinal.png)
#
#   2.- Solución en Python
#   Se muestra en las lineas siguientes.
#
#   Conclusión:
#   Como podemos observar, resolver a papel y lapiz es un proceso muy largo, a demas de que se pueda obtener algun error a la hora de realizar los  calculos, tambien podemos observr que mediante la programacion para resolver se obtienen resultados mas exactos.
#
#   ___
#   #### Xochitl Atanacio Sánchez

# %%
import numpy
import numpy.linalg
A=numpy.array([[3.2,-1,2],[2,-2,4],[1.5,-1,-4]])
e_values, e_vectors=numpy.linalg.eig(A)
e_values
# Out:
# array([ 2.965908+0.j        , -2.882954+0.76793809j,
#        -2.882954-0.76793809j])

# %%
e_vectors
# Out:
# array([[ 0.88158576+0.j        , -0.256879  +0.02847007j,
#         -0.256879  -0.02847007j],
#        [ 0.45531661+0.j        , -0.89064266+0.j        ,
#         -0.89064266-0.j        ],
#        [ 0.12447222+0.j        ,  0.32503863-0.18522464j,
#          0.32503863+0.18522464j]])
